# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ubco-W2022T2-data301/project-group43/main/data/raw/FT1000.csv?token=GHSAT0AAAAAAB5P32QDJDRSZPKNUYC3HYSQZABGEZA')
df
# Out:
#      Rank            Name Ranked2021 Ranked2020    Country  \
# 0       1         Swappie         No         No    Finland
# 1       2     Kilo Health         No         No  Lithuania
# 2       3             OCI         No         No         UK
# 3       4        OnlyFans         No         No         UK
# 4       5           Enpal         No         No    Germany
# ..    ...             ...        ...        ...        ...
# 995   996  peopleForecast         No         No    Germany
# 996   997       Digitalpa         No         No      Italy
# 997   998    Faktenkontor         No         No    Germany
# 998   999          CLAREO        Yes        Yes     France
# 999  1000      Laca Trade        Yes        Yes      Italy
#
#                     Sector    CAGR  Revenue2020  Revenue2017  Employees2020  \
# 0               Technology  477.43     97611814       507000            218
# 1                   Health  450.05     57318766       344428            177
# 2       Financial Services  409.59    568322073      4325512             32
# 3               Technology  393.63    316732986      2652185            800
# 4                   Energy  386.88     56109613       486165            365
# ..                     ...     ...          ...          ...            ...
# 995             Technology   36.59      2086411       818658             45
# 996  Management Consulting   36.59      1731340       679440             12
# 997            Advertising   36.59     30967000     12153143            150
# 998                 Retail   36.58     18854708      7399729             53
# 999               Property   36.55     24741510      9717860              5
#
#      Employees2017  FoundingYear
# 0                1          2016
# 1               10          2013
# 2                4          2012
# 3                4          2016
# 4                9          2017
# ..             ...           ...
# 995             15          2014
# 996             41          2014
# 997            100          2003
# 998             13          2012
# 999              5          2013
#
# [1000 rows x 12 columns]

# %%
df=df.drop(columns=['Ranked2021','Ranked2020','Country','Sector'])
df
# Out:
#      Rank            Name    CAGR  Revenue2020  Revenue2017  Employees2020  \
# 0       1         Swappie  477.43     97611814       507000            218
# 1       2     Kilo Health  450.05     57318766       344428            177
# 2       3             OCI  409.59    568322073      4325512             32
# 3       4        OnlyFans  393.63    316732986      2652185            800
# 4       5           Enpal  386.88     56109613       486165            365
# ..    ...             ...     ...          ...          ...            ...
# 995   996  peopleForecast   36.59      2086411       818658             45
# 996   997       Digitalpa   36.59      1731340       679440             12
# 997   998    Faktenkontor   36.59     30967000     12153143            150
# 998   999          CLAREO   36.58     18854708      7399729             53
# 999  1000      Laca Trade   36.55     24741510      9717860              5
#
#      Employees2017  FoundingYear
# 0                1          2016
# 1               10          2013
# 2                4          2012
# 3                4          2016
# 4                9          2017
# ..             ...           ...
# 995             15          2014
# 996             41          2014
# 997            100          2003
# 998             13          2012
# 999              5          2013
#
# [1000 rows x 8 columns]

# %%
sns.scatterplot(x='Employees2020',y='CAGR',data=df)
plt.xlabel('Number of Employees 2020')
plt.ylabel('CAGR')
# Out:
# Text(0, 0.5, 'CAGR')

# %%
sns.scatterplot(x='Employees2020',y='Revenue2020',data=df)
plt.xlabel('Revenue 2020')
plt.ylabel('Number of Employees 2020')
# Out:
# Text(0, 0.5, 'Number of Employees 2020')

# %%
sns.scatterplot(x='Employees2017',y='Revenue2017',data=df)
plt.xlabel('Revenue 2017')
plt.ylabel('Number of Employees 2017')
# Out:
# Text(0, 0.5, 'Number of Employees 2017')

# %%
sns.lmplot(x='Employees2017',y='Revenue2017',data=df)
plt.xlabel('Revenue 2017')
plt.ylabel('Number of Employees 2017')
# Out:
# Text(29.000000000000007, 0.5, 'Number of Employees 2017')

# %%
sns.lmplot(x='Employees2020',y='Revenue2020',data=df)
plt.xlabel('Revenue 2020')
plt.ylabel('Number of Employees 2020')
# Out:
# Text(29.000000000000007, 0.5, 'Number of Employees 2020')
