# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/ubco-W2022T2-data301/project-group43/main/data/raw/FT1000.csv?token=GHSAT0AAAAAAB5TSZLNKSM3CWMEJM5FYPJWZA4YPLQ")
df
# Out:
#      Rank            Name Ranked2021 Ranked2020    Country  \
# 0       1         Swappie         No         No    Finland
# 1       2     Kilo Health         No         No  Lithuania
# 2       3             OCI         No         No         UK
# 3       4        OnlyFans         No         No         UK
# 4       5           Enpal         No         No    Germany
# ..    ...             ...        ...        ...        ...
# 995   996  peopleForecast         No         No    Germany
# 996   997       Digitalpa         No         No      Italy
# 997   998    Faktenkontor         No         No    Germany
# 998   999          CLAREO        Yes        Yes     France
# 999  1000      Laca Trade        Yes        Yes      Italy
#
#                     Sector    CAGR  Revenue2020  Revenue2017  Employees2020  \
# 0               Technology  477.43     97611814       507000            218
# 1                   Health  450.05     57318766       344428            177
# ...

# %%
delimiters = [',', ';', '\t', '|']

for delimiter in delimiters:
    try:
        df = pd.read_csv(pd.compat.StringIO(df.to_csv(index=False)), delimiter=delimiter)
        print(f"Delimiter found: '{delimiter}'")
        break
    except:
        pass

# %%
### No Delimeter Found

# %%
### Delete blank Rows and Columns

# %%
### Delete Rows and Columns with empty values
df = df.dropna(axis=0)
df = df.dropna(axis=1)
df
# Out:
#      Rank            Name                 Sector    CAGR  Revenue2020  \
# 0       1         Swappie             Technology  477.43     97611814
# 1       2     Kilo Health                 Health  450.05     57318766
# 2       3             OCI     Financial Services  409.59    568322073
# 3       4        OnlyFans             Technology  393.63    316732986
# 4       5           Enpal                 Energy  386.88     56109613
# ..    ...             ...                    ...     ...          ...
# 995   996  peopleForecast             Technology   36.59      2086411
# 996   997       Digitalpa  Management Consulting   36.59      1731340
# 997   998    Faktenkontor            Advertising   36.59     30967000
# 998   999          CLAREO                 Retail   36.58     18854708
# 999  1000      Laca Trade               Property   36.55     24741510
#
#      Revenue2017  Employees2020  Employees2017
# 0         507000            218              1
# ...

# %%
### No Missing Data

# %%
df = df.drop(columns=['Ranked2021','Ranked2020','Country', 'FoundingYear'])
df
# Out:
#      Rank            Name                 Sector    CAGR  Revenue2020  \
# 0       1         Swappie             Technology  477.43     97611814
# 1       2     Kilo Health                 Health  450.05     57318766
# 2       3             OCI     Financial Services  409.59    568322073
# 3       4        OnlyFans             Technology  393.63    316732986
# 4       5           Enpal                 Energy  386.88     56109613
# ..    ...             ...                    ...     ...          ...
# 995   996  peopleForecast             Technology   36.59      2086411
# 996   997       Digitalpa  Management Consulting   36.59      1731340
# 997   998    Faktenkontor            Advertising   36.59     30967000
# 998   999          CLAREO                 Retail   36.58     18854708
# 999  1000      Laca Trade               Property   36.55     24741510
#
#      Revenue2017  Employees2020  Employees2017
# 0         507000            218              1
# ...

# %%
df = df.groupby("Sector").mean()
df
# Out:
# /var/folders/sj/4nd0jmvd1r34z0nxpz56c1w00000gn/T/ipykernel_6109/1056443800.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby("Sector").mean()
#                                     Rank        CAGR   Revenue2020  \
# Sector
# Advertising                   491.181818   74.794242  9.761134e+06
# Aerospace & Defence           605.666667   62.668333  1.153957e+07
# Agricultural Commodities      558.428571   59.501429  2.245109e+07
# Architecture                  513.000000   60.265000  3.738828e+06
# Automobiles                   562.307692   65.572692  1.453354e+07
# Batteries                      93.000000  138.520000  7.406541e+07
# Beauty                        443.400000   89.174000  5.107593e+06
# Chemicals & Pharmaceuticals   517.750000   68.720000  4.545890e+06
# ...

# %%
df['Change % in Revenue'] = ((df['Revenue2020'] - df['Revenue2017']) / df['Revenue2017']) * 100

df
# Out:
#                                     Rank        CAGR   Revenue2020  \
# Sector
# Advertising                   491.181818   74.794242  9.761134e+06
# Aerospace & Defence           605.666667   62.668333  1.153957e+07
# Agricultural Commodities      558.428571   59.501429  2.245109e+07
# Architecture                  513.000000   60.265000  3.738828e+06
# Automobiles                   562.307692   65.572692  1.453354e+07
# Batteries                      93.000000  138.520000  7.406541e+07
# Beauty                        443.400000   89.174000  5.107593e+06
# Chemicals & Pharmaceuticals   517.750000   68.720000  4.545890e+06
# Construction                  541.123596   66.093258  1.099944e+07
# Cyber Security                482.400000   74.656000  2.461367e+07
# Ecommerce                     493.353846   79.267538  2.997469e+07
# Education                     472.000000   83.011333  7.089277e+06
# Energy                        492.595238   84.310238  8.358919e+07
# ...

# %%
df_CAGR = df.sort_values(by='CAGR', ascending=False)
df_CAGR
# Out:
#                                     Rank        CAGR   Revenue2020  \
# Sector
# Batteries                      93.000000  138.520000  7.406541e+07
# Fintech                       274.730769  111.459615  3.214180e+07
# Games industry                447.250000   98.537500  1.200823e+08
# Personal & Household Goods    347.700000   98.099000  2.771231e+07
# Food & Beverage               441.150000   93.661500  2.822042e+07
# Financial Services            475.000000   92.912143  3.589247e+07
# Waste management & recycling  448.916667   91.444167  1.008245e+07
# Fashion                       493.200000   90.037000  1.354491e+07
# Property                      463.884615   89.887308  2.607857e+07
# Beauty                        443.400000   89.174000  5.107593e+06
# Health                        499.069767   86.522558  1.264009e+07
# Pharmaceuticals               476.200000   85.824000  1.111977e+07
# Energy                        492.595238   84.310238  8.358919e+07
# ...

# %%
df_revenue = df.sort_values(by='Change % in Revenue', ascending=False)
df_revenue
# Out:
#                                     Rank        CAGR   Revenue2020  \
# Sector
# Batteries                      93.000000  138.520000  7.406541e+07
# Financial Services            475.000000   92.912143  3.589247e+07
# Pharmaceuticals               476.200000   85.824000  1.111977e+07
# Energy                        492.595238   84.310238  8.358919e+07
# Fintech                       274.730769  111.459615  3.214180e+07
# Cyber Security                482.400000   74.656000  2.461367e+07
# Waste management & recycling  448.916667   91.444167  1.008245e+07
# Technology                    477.976077   83.933636  1.919595e+07
# Property                      463.884615   89.887308  2.607857e+07
# Health                        499.069767   86.522558  1.264009e+07
# Beauty                        443.400000   89.174000  5.107593e+06
# Media                         485.090909   68.810000  9.131486e+06
# Food & Beverage               441.150000   93.661500  2.822042e+07
# ...

# %%
### Method Chain 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = (
pd.read_csv("https://raw.githubusercontent.com/ubco-W2022T2-data301/project-group43/main/data/raw/FT1000.csv?token=GHSAT0AAAAAAB5TSZLMQDIINVIVO5FOECNGZA4552Q")
    .drop(columns=['Ranked2021', 'Ranked2020', 'Country', 'FoundingYear'])
    .groupby('Sector')
    .mean()
    .assign(change_in_revenue=lambda x: ((x['Revenue2020'] - x['Revenue2017']) / x['Revenue2017']) * 100)
    .sort_values('CAGR', ascending=False)
)
df
# Out:
# /var/folders/sj/4nd0jmvd1r34z0nxpz56c1w00000gn/T/ipykernel_16534/4074709919.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#                                     Rank        CAGR   Revenue2020  \
# Sector
# Batteries                      93.000000  138.520000  7.406541e+07
# Fintech                       274.730769  111.459615  3.214180e+07
# Games industry                447.250000   98.537500  1.200823e+08
# Personal & Household Goods    347.700000   98.099000  2.771231e+07
# Food & Beverage               441.150000   93.661500  2.822042e+07
# Financial Services            475.000000   92.912143  3.589247e+07
# Waste management & recycling  448.916667   91.444167  1.008245e+07
# Fashion                       493.200000   90.037000  1.354491e+07
# ...
